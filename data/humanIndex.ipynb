# %% [markdown]
# ## Using pandas to read the global human index

# %%
import pandas as pd

dataframe = pd.read_csv('./humanIndex.csv')

print(dataframe)
# Out:
#     ISO3               Country Human Development Groups  \
# 0    AFG           Afghanistan                      Low
# 1    AGO                Angola                   Medium
# 2    ALB               Albania                     High
# 3    AND               Andorra                Very High
# 4    ARE  United Arab Emirates                Very High
# ..   ...                   ...                      ...
# 190  WSM                 Samoa                     High
# 191  YEM                 Yemen                      Low
# 192  ZAF          South Africa                     High
# 193  ZMB                Zambia                   Medium
# 194  ZWE              Zimbabwe                   Medium
#
#     UNDP Developing Regions  HDI Rank (2021)  Human Development Index (1990)  \
# 0                        SA            180.0                           0.273
# 1                       SSA            148.0                             NaN
# ...

# %% [markdown]
# ## Get an overview of the dataframe

# %%
dataframe.describe()

# %% [markdown]
# ## Get the data dimension

# %%
dataframe.shape
# Out:
# (195, 880)

# %% [markdown]
# ## Studying what the different columns represent

# %%
pd.set_option('display.max_columns', None)
dataframe
# Out:
#     ISO3               Country Human Development Groups  \
# 0    AFG           Afghanistan                      Low
# 1    AGO                Angola                   Medium
# 2    ALB               Albania                     High
# 3    AND               Andorra                Very High
# 4    ARE  United Arab Emirates                Very High
# ..   ...                   ...                      ...
# 190  WSM                 Samoa                     High
# 191  YEM                 Yemen                      Low
# 192  ZAF          South Africa                     High
# 193  ZMB                Zambia                   Medium
# 194  ZWE              Zimbabwe                   Medium
#
#     UNDP Developing Regions  HDI Rank (2021)  Human Development Index (1990)  \
# 0                        SA            180.0                           0.273
# 1                       SSA            148.0                             NaN
# ...

# %% [markdown]
# ## Interesting columns to explore are as follows:
# ## country, human development groups (2021) inequality in education (2021), human development index group (2021), life expectancy at birth female and male (2021)

# %%
humanindextwentyone = dataframe['Human Development Index (2021)']
humandevelopmentgroups = dataframe['Human Development Groups']
country = dataframe['Country']
inequalityInEducation = dataframe['Inequality in eduation (2021)']
lifeexpectancyatbirthfemale = dataframe['Life Expectancy at Birth, female (2021)']
lifeexpectancyatbirthmale =  dataframe['Life Expectancy at Birth, male (2021)']

print(humanindextwentyone)
print(country)
print(inequalityInEducation)
print(lifeexpectancyatbirthfemale)
print(lifeexpectancyatbirthmale)
print(humandevelopmentgroups)
# Out:
# 0      0.478
# 1      0.586
# 2      0.796
# 3      0.858
# 4      0.911
#        ...
# 190    0.707
# 191    0.455
# 192    0.713
# 193    0.565
# 194    0.593
# Name: Human Development Index (2021), Length: 195, dtype: float64
# 0               Afghanistan
# 1                    Angola
# 2                   Albania
# 3                   Andorra
# 4      United Arab Emirates
#                ...
# 190                   Samoa
# 191                   Yemen
# 192            South Africa
# 193                  Zambia
# 194                Zimbabwe
# Name: Country, Length: 195, dtype: object
# 0      45.365170
# 1      34.171440
# 2      12.333440
# 3      10.008154
# 4      12.634355
#          ...
# 190     7.029960
# 191    46.137650
# 192    17.294130
# 193    20.435720
# 194    14.605030
# Name: Inequality in eduation (2021), Length: 195, dtype: float64
# 0      65.2791
# 1      64.3066
# 2      79.1726
# 3      84.3238
# 4      80.9371
#         ...
# 190    75.5034
# ...

# %% [markdown]
# ## Understanding the data types of the chosen columns- The types are between floats and object

# %%
humanindextwentyone = dataframe['Human Development Index (2021)'].dtype
country = dataframe['Country'].dtype
gendereinequality = dataframe['Inequality in eduation (2021)'].dtype
lifeexpectancyatbirthfemale = dataframe['Life Expectancy at Birth, female (2021)'].dtype
lifeexpectancyatbirthmale =  dataframe['Life Expectancy at Birth, male (2021)'].dtype

print(humanindextwentyone)
print(country)
print(gendereinequality)
print(lifeexpectancyatbirthfemale)
print(lifeexpectancyatbirthmale)
# Out:
# float64
# object
# float64
# float64
# float64

# %% [markdown]
# ## The chosen data types displayed in columns

# %%
subset = dataframe[['Country','Human Development Groups', 'Human Development Index (2021)', 'Inequality in eduation (2021)', 'Life Expectancy at Birth, female (2021)', 'Life Expectancy at Birth, male (2021)' ]]
subset.head(20)
# Out:
#                    Country Human Development Groups  \
# 0              Afghanistan                      Low
# 1                   Angola                   Medium
# 2                  Albania                     High
# 3                  Andorra                Very High
# 4     United Arab Emirates                Very High
# 5                Argentina                Very High
# 6                  Armenia                     High
# 7      Antigua and Barbuda                     High
# 8                Australia                Very High
# 9                  Austria                Very High
# 10              Azerbaijan                     High
# 11                 Burundi                      Low
# 12                 Belgium                Very High
# 13                   Benin                      Low
# 14            Burkina Faso                      Low
# 15              Bangladesh                   Medium
# 16                Bulgaria                     High
# ...

# %% [markdown]
# ## Remove all rows with null values from the dataframe

# %%
subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].dropna()
# Out:
#           Country Human Development Groups  Human Development Index (2021)  \
# 63          Ghana                   Medium                           0.632
# 65         Gambia                      Low                           0.500
# 115          Mali                      Low                           0.428
# 152       Senegal                      Low                           0.511
# 192  South Africa                     High                           0.713
#
#      Inequality in eduation (2021)  Life Expectancy at Birth, female (2021)  \
# 63                        35.10167                                  66.0136
# 65                        47.00005                                  63.5287
# 115                       43.85965                                  60.3310
# 152                       47.13530                                  69.2838
# 192                       17.29413                                  64.9992
#
#      Life Expectancy at Birth, male (2021)
# ...

# %% [markdown]
# ## Check if there are missing values
# <p> The data shows that 19 of Inequality in education are missing as well as 4 of the human developement groups are missing. It will be probably difficult to draw conclusion in the data</p>

# %%
subset.isnull().sum()
# Out:
# Country                                     0
# Human Development Groups                    4
# Human Development Index (2021)              4
# Inequality in eduation (2021)              19
# Life Expectancy at Birth, female (2021)     0
# Life Expectancy at Birth, male (2021)       0
# dtype: int64

# %% [markdown]
# ## An overview of the chosen columns

# %%
subset.describe()
# Out:
#        Human Development Index (2021)  Inequality in eduation (2021)  \
# count                      191.000000                     176.000000
# mean                         0.720576                      18.006314
# std                          0.150661                      14.569313
# min                          0.385000                       0.550110
# 25%                          0.599500                       5.518733
# 50%                          0.739000                      12.843558
# 75%                          0.835000                      28.335352
# max                          0.962000                      50.124110
#
#        Life Expectancy at Birth, female (2021)  \
# count                               195.000000
# mean                                 74.034113
# std                                   7.879224
# min                                  53.070100
# 25%                                  68.454750
# 50%                                  75.175200
# ...

# %% [markdown]
# ## 18 percent are challenged by inequality in education

# %%
subset['Inequality in eduation (2021)'].mean()
# Out:
# 18.006313952028407

# %% [markdown]
# ## Human development index (2021) is set to 72 percent

# %%
subset['Human Development Index (2021)'].mean()
# Out:
# 0.7232102272727273

# %% [markdown]
# ## Life expectancy at birth, female (2021) is set to 74

# %%
subset['Life Expectancy at Birth, female (2021)'].mean()
# Out:
# 74.05634772727272

# %% [markdown]
# ## Life expectancy at birth, male (2021) is set to 68

# %%
subset['Life Expectancy at Birth, male (2021)'].mean()
# Out:
# 68.65260454545454

# %% [markdown]
# ## Comparison life expectancy at birth for female is at 53 percent and 88 percent for male

# %%
subset.groupby(['Life Expectancy at Birth, female (2021)'])['Life Expectancy at Birth, male (2021)'].mean()
# Out:
# Life Expectancy at Birth, female (2021)
# 53.0701    52.2846
# 54.2828    50.8449
# 55.9266    50.3736
# 56.3035    51.6455
# 56.4723    53.4286
#             ...
# 86.1085    81.4414
# 86.7603    80.3864
# 87.6773    84.3428
# 87.7313    81.8018
# 88.3257    82.6613
# Name: Life Expectancy at Birth, male (2021), Length: 195, dtype: float64

# %% [markdown]
# ## Senegal, Gambia, Mali, Ghana and South Africa are the chosen countries that are explored in this project.
# ## Extracting data for the countries human developement groups which show and all low for Gambia, Senegal, and Mali.
# ## Medium for Ghana and high South Africa.
# ## This decripancies are also connected to the human development index, inequality in education and life expectancy at birth for both female and male

# %%
subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].head()
# Out:
#           Country Human Development Groups  Human Development Index (2021)  \
# 63          Ghana                   Medium                           0.632
# 65         Gambia                      Low                           0.500
# 115          Mali                      Low                           0.428
# 152       Senegal                      Low                           0.511
# 192  South Africa                     High                           0.713
#
#      Inequality in eduation (2021)  Life Expectancy at Birth, female (2021)  \
# 63                        35.10167                                  66.0136
# 65                        47.00005                                  63.5287
# 115                       43.85965                                  60.3310
# 152                       47.13530                                  69.2838
# 192                       17.29413                                  64.9992
#
#      Life Expectancy at Birth, male (2021)
# ...

# %% [markdown]
# ## Interesting data in regards to the means of the five countries

# %%
subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].groupby(['Country']).mean()
# Out:
# C:\Users\aisha\AppData\Local\Temp\ipykernel_5268\4033831776.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].groupby(['Country']).mean()
#               Human Development Index (2021)  Inequality in eduation (2021)  \
# Country
# Gambia                                 0.500                       47.00005
# Ghana                                  0.632                       35.10167
# Mali                                   0.428                       43.85965
# Senegal                                0.511                       47.13530
# South Africa                           0.713                       17.29413
# ...

# %% [markdown]
# ## The relationship between each variable
# ## The theories regarding the correlations is that there is a perfect correlation between Human Development Index, Inequality in education,
# ## Life expectancy at birth, female and Life expectany at birth, male.

# %%
subset.corr()
# Out:
# C:\Users\aisha\AppData\Local\Temp\ipykernel_5268\1219836613.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   subset.corr()
#                                          Human Development Index (2021)  \
# Human Development Index (2021)                                 1.000000
# Inequality in eduation (2021)                                 -0.814650
# Life Expectancy at Birth, female (2021)                        0.921440
# Life Expectancy at Birth, male (2021)                          0.892591
#
#                                          Inequality in eduation (2021)  \
# Human Development Index (2021)                               -0.814650
# Inequality in eduation (2021)                                 1.000000
# Life Expectancy at Birth, female (2021)                      -0.699629
# ...

# %% [markdown]
# ## Visual view of the correlation of between the 5 choosen colums
# <p> The data shows a clear correlation between human development index and inequality index
#     As well as inequaliity in education and life expectancy at bith for female.
#     The same goes for inequality in education and life expecctancy at birth at birth.
#     Overall, a stronger correlation between human developemnt index and life expectancy at
#     birth for male.
# </p>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.heatmap(subset.corr(), annot=True, fmt=".2f")
plt.show()
# Out:
# C:\Users\aisha\AppData\Local\Temp\ipykernel_5268\1473724872.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(subset.corr(), annot=True, fmt=".2f")

# %% [markdown]
# ## Visualizual representation of data Country vs Human Developement Index (2021)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

# %%
subset.plot(kind='scatter', x='Country', y='Human Development Index (2021)', title='Country vs Human Development Index(2021)');

# %%
country = subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].head()

# %% [markdown]
# ## Comaprison between life expectancy at birth, female and human development index

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.lmplot(x='Life Expectancy at Birth, female (2021)', y='Human Development Index (2021)', data=subset)

# %% [markdown]
# ## Comaprison between life expectancy at birth, male and human development index

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.lmplot(x='Life Expectancy at Birth, male (2021)', y='Human Development Index (2021)', data=subset)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.lmplot(x='Inequality in eduation (2021)', y='Human Development Index (2021)', data=subset)

# %% [markdown]
# ## Visual representation of the five countries in terms of inequality in education, human development index, human development groups, life expectancy at birth for female and male are as follows.:

# %%
subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].groupby(['Country']).mean().plot.bar()
# Out:
# C:\Users\aisha\AppData\Local\Temp\ipykernel_5268\173254704.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subset[(subset['Country'] == 'Senegal') | (subset['Country'] == 'Gambia') | (subset['Country'] == 'Ghana') | (subset['Country'] == 'Mali')  | (subset['Country'] == 'South Africa')].groupby(['Country']).mean().plot.bar()
# <AxesSubplot: xlabel='Country'>

# %% [markdown]
# ## In conclusion
#
# ## Human development index
#  <p> Lowest is Gambia and Senegal and the highest is Ghana and South Africa.
#
# ## In equality ineducation
# <p> The visual representation shows that South africa has the lowest inequality in education in 2021. Followed by Ghana. In comparison to Mali, and Senegal and Gambia. Actually Senegal and Gambia are closed to hiighest in equaity in education. However, Gambia set an all record high in comparison to the five countries explored in this data.
# <p>
#
# ## Life expectancy at birth, female (2021)
# <p>Senegal shows the highest record. Followed by Ghana, South Africa, Gambia. Mali scoring the lowest.
#
# ## Life expectation at birth, male (2021)
# <p> Senegal shows the higest record in that context too. Followed by Ghana, South Africa, Gambia. Mali scoring the lowest.

# %% [markdown]
# ## Why this conclusion?
# <p> A question to ask is, if South Africa has the lowest inequality in education but a very high record of life expectancy at birth for female. Does that mean the two has no relationship or if so, why this much disparity. One could ask the same question for Ghana.
# <p>An interesting discovery is that Mali has the lowest when it come life expectancy for female and male at birth and third lowest when it come inequality in education.
# <p> Another intresting discovery is that South Africa is scores the highest when it comes to the human development index (2021). Followed by Ghana, Senegal, and Mali. With Gambia the lowest.
